# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar8910/python_from_beginning/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**python**
# In This session we learn about Operators and Booleans values.
# Operators are special symbols that perform operations on variables and values.
#  In python there different operators :
#
# * Arithmetic operators
# * Assignment operators
# * Comparison operators
# * Logical operators
# * Identity operators
# * Membership operators
# * Bitwise operators
#
# **Arithmetic Operators in Python**
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, division, modulo,power, floor division.
# Operation
# * (+)	Addition	3 + 3 = 6
# * (-)	Subtraction	3 - 1 = 2
# * (*)	Multiplication	3 * 3 = 9
# * (/) Division	6 / 2 =3
# * (//)	Floor Division	20 // 6 = 3
# * (%)	Modulo	5 % 2 = 1
# * (**)	Power	5 ** 2 = 25

# %%
a = 232
b = 28

print ('Sum: ', a + b)  

print ('Subtraction: ', a - b)   

print ('Multiplication: ', a * b)  

print ('Division: ', a / b) 

print ('Floor Division: ', a // b)

print ('Modulo: ', a % b)  

print ('Power: ', a ** b)
# Out:
# Sum:  260
# Subtraction:  204
# Multiplication:  6496
# Division:  8.285714285714286
# Floor Division:  8
# Modulo:  8
# Power:  1712630117088855961988429465379924025998117531670739376695280664576

# %% [markdown]
# **Python Assignment Operators**  :
# Assignment operators are used to assign values to variables.
# ![image.png](data:image/png;base64,...)

# %%
a = 23
b = 5 


a += b     

print(a)
# Out:
# 28

# %%
a = 23
b = 5 


a *= b     

print(a)
# Out:
# 115

# %%
a = 23
b = 5 


a -= b     

print(a)
# Out:
# 18

# %%
a = 23
b = 5 


a /= b     

print(a)
# Out:
# 4.6

# %% [markdown]
# **Comparison Operators**
# Comparison operators compare two values/variables and return a boolean result: True or False.![image.png](data:image/png;base64,...)

# %%
a = 3984
b =589

print (a > b)
# Out:
# True

# %%
a = 3984
b =589

print (a < b)
# Out:
# False

# %% [markdown]
# **Logical Operators**
# Logical operators are used to check whether an expression is True or False. They are used in decision-making.![image.png](data:image/png;base64,...)

# %%
print(True and True)     
print(True and False)    

print(True or False)     

print(not True)
# Out:
# True
# False
# True
# False

# %% [markdown]
# **Bitwise operators**
# Bitwise operators act on operands as if they were strings of binary digits. ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Membership operators**
# In Python, in and not in are the membership operators. They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).![image.png](data:image/png;base64,...)

# %%
x = 'Python programming'
y = {8:'s', 2:'g'}

print('p' in x)  
print('programming' not in x) 
print(8 in y)  
print('g' in y)
# Out:
# True
# False
# True
# False

# %% [markdown]
# **Boolens in python**
# The Python Boolean type has only two possible values:
#
# * True
# * False
#
# No other value will have bool as its type. You can check the type of True and False with the built-in type():

# %%
print( 75> 34)
print(34 == 75)
print(164 < 34)
# Out:
# True
# False
# False

# %%
x = 5
y = 10
print(bool(x==y))
print(type(x==y))

x = None
print(bool(x))
print(type(x))

x = ()
print(bool(x))
print(type(x))


x = {}
print(bool(x))
print(type(x))


x = 0.0
print(bool(x))
print(type(x))

x = 'python'
print(bool(x))
print(type(x))
# Out:
# False
# <class 'bool'>
# False
# <class 'NoneType'>
# False
# <class 'tuple'>
# False
# <class 'dict'>
# False
# <class 'float'>
# True
# <class 'str'>

# %% [markdown]
# **Boolean Operators**
# Boolean Operations are simple arithmetic of True and False values. These values can be manipulated by the use of boolean operators which include AND, Or, and NOT.
#
# * or
# * and
# * not
# * == (equivalent)
# * != (not equivalent)
#
# **Boolean OR Operator**
# The Boolean or operator returns True if any one of the inputs is True else returns False.
#
# ![image.png](data:image/png;base64,...)

# %%
x = 82
y = 2
z = 4
if x > y or y < z:
	print(True)
else:
	print(False)

if x or y or z:
	print("python progamming")
#'''we have used Python boolean with if statement and OR operator that check if x is greater than y or y is smaller than z and it returns True if any of the condition is True'''
# Out:
# True
# python progamming

# %% [markdown]
# **Boolean And Operator**
# The Boolean and operator returns False if any one of the inputs is False else returns True.
# ![image.png](data:image/png;base64,...)

# %%
a = 0
b = 2
c = 4

if a > b and b<c:
	print(True)
else:
	print(False)
	
if a and b and c:
	print("All the numbers has boolean value as True")
else:
	print("Atleast one number has boolean value as False")
# Out:
# False
# Atleast one number has boolean value as False

# %% [markdown]
# **Boolean Not Operator**
# The Boolean Not operator only require one argument and returns the negation of the argument i.e. returns the True for False and False for True.
# ![image.png](data:image/png;base64,...)

# %%
a = 0

if not a:
	print("Boolean value of a is False")
# Out:
# Boolean value of a is False

# %% [markdown]
# **Boolean == (equivalent) and != (not equivalent) Operator**
# Both the operators are used to compared two results. == (equivalent operator returns True if two results are equal and != (not equivalent operator returns True if the two results are not same.

# %%
a = 0
b = 1

if a == 0:
	print(True)
	
if a == b:
	print(True)
	
if a != b:
  print(True)
# Out:
# True
# True
